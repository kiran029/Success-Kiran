# %% [markdown]
# <a href="https://colab.research.google.com/github/kiran029/Success-Kiran/blob/main/EDA1_HeartDisease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn as sns

# %%
data_1=pd.read_csv("/content/drive/MyDrive/dataset_heart.csv")

# %%
data_1
# Out:
#      age  sex   chest pain type  resting blood pressure  serum cholestoral  \
# 0     70     1                4                     130                322
# 1     67     0                3                     115                564
# 2     57     1                2                     124                261
# 3     64     1                4                     128                263
# 4     74     0                2                     120                269
# ..   ...   ...              ...                     ...                ...
# 265   52     1                3                     172                199
# 266   44     1                2                     120                263
# 267   56     0                2                     140                294
# 268   57     1                4                     140                192
# 269   67     1                4                     160                286
#
#      fasting blood sugar  resting electrocardiographic results  \
# ...

# %%
type(data_1)
data_1.shape
# Out:
# (270, 14)

# %%
data_1.describe()
# Out:
#               age        sex   chest pain type  resting blood pressure  \
# count  270.000000  270.000000       270.000000              270.000000
# mean    54.433333    0.677778         3.174074              131.344444
# std      9.109067    0.468195         0.950090               17.861608
# min     29.000000    0.000000         1.000000               94.000000
# 25%     48.000000    0.000000         3.000000              120.000000
# 50%     55.000000    1.000000         3.000000              130.000000
# 75%     61.000000    1.000000         4.000000              140.000000
# max     77.000000    1.000000         4.000000              200.000000
#
#        serum cholestoral  fasting blood sugar  \
# count         270.000000           270.000000
# mean          249.659259             0.148148
# std            51.686237             0.355906
# min           126.000000             0.000000
# 25%           213.000000             0.000000
# ...

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   age                                   270 non-null    int64
#  1   sex                                   270 non-null    int64
#  2   chest pain type                       270 non-null    int64
#  3   resting blood pressure                270 non-null    int64
#  4   serum cholestoral                     270 non-null    int64
#  5   fasting blood sugar                   270 non-null    int64
#  6   resting electrocardiographic results  270 non-null    int64
#  7   max heart rate                        270 non-null    int64
#  8   exercise induced angina               270 non-null    int64
#  9   oldpeak                               270 non-null    float64
#  10  ST segment                            270 non-null    int64
# ...

# %%
data_2=data_1.rename({'age':'Age','sex ':'Gender','chest pain type':'CPT','resting blood pressure':'RBP','serum cholestoral':'SC','fasting blood sugar':'FBS','resting electrocardiographic results':'RER','max heart rate':'MHR','exercise induced angina':'EIA','ST segment':'ST','major vessels':'MV','heart disease':'Result'}, axis=1)
print(data_2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Age      270 non-null    int64
#  1   Gender   270 non-null    int64
#  2   CPT      270 non-null    int64
#  3   RBP      270 non-null    int64
#  4   SC       270 non-null    int64
#  5   FBS      270 non-null    int64
#  6   RER      270 non-null    int64
#  7   MHR      270 non-null    int64
#  8   EIA      270 non-null    int64
#  9   oldpeak  270 non-null    float64
#  10  ST       270 non-null    int64
#  11  MV       270 non-null    int64
#  12  thal     270 non-null    int64
#  13  Result   270 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 29.7 KB
# None

# %%
#data = data.applymap(lambda x: x.strip() if isinstance(x, str) else x) Used to remove trailing/leading space
#data_3=data_2.copy()
#data_3['Gender']=data_2['sex ']

# %%
data_2.head(20)
# Out:
#     Age  Gender  CPT  RBP   SC  FBS  RER  MHR  EIA  oldpeak  ST  MV  thal  \
# 0    70       1    4  130  322    0    2  109    0      2.4   2   3     3
# 1    67       0    3  115  564    0    2  160    0      1.6   2   0     7
# 2    57       1    2  124  261    0    0  141    0      0.3   1   0     7
# 3    64       1    4  128  263    0    0  105    1      0.2   2   1     7
# 4    74       0    2  120  269    0    2  121    1      0.2   1   1     3
# 5    65       1    4  120  177    0    0  140    0      0.4   1   0     7
# 6    56       1    3  130  256    1    2  142    1      0.6   2   1     6
# 7    59       1    4  110  239    0    2  142    1      1.2   2   1     7
# 8    60       1    4  140  293    0    2  170    0      1.2   2   2     7
# 9    63       0    4  150  407    0    2  154    0      4.0   2   3     7
# 10   59       1    4  135  234    0    0  161    0      0.5   2   0     7
# 11   53       1    4  142  226    0    2  111    1      0.0   1   0     7
# ...

# %%
sns.pairplot(data_2)

# %% [markdown]
# # Outlier Detection

# %%
# I see extreme values in Serum Cholesterol, Herat Rate and BP

# %%
#Box plot
data_box=data_2.dropna()
data1_box=data_box.SC
plt.boxplot(data1_box)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ee2ad4bfa60>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ee2ad4bffa0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ee2ad4be680>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ee2ad4dc520>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ee2ad4dc7c0>],
#  'means': []}

# %%
#Box plot
data_box=data_2.dropna()
data1_box=data_box.RBP
plt.boxplot(data1_box)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ee2ad3ea380>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ee2ad3ea8c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ee2ad497fa0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ee2ad3eae00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ee2ad3eb0a0>],
#  'means': []}

# %%
#Box plot
data_box=data_2.dropna()
data1_box=data_box.MHR
plt.boxplot(data1_box)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ee2ad1498d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ee2ad149e10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ee2ad149630>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ee2ad14a350>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ee2ad2a45b0>],
#  'means': []}

# %%
import seaborn as sns
cols = data_2.columns
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(data_2[cols].isnull(),
            cmap=sns.color_palette(colours))
# Out:
# <Axes: >

# %%
sns.barplot(data_2, x='Result',y='Age')
# Out:
# <Axes: xlabel='Result', ylabel='Age'>

# %%
sns.barplot(data_2, x='Result',y='Gender')
# Out:
# <Axes: xlabel='Result', ylabel='Gender'>

# %%
sns.scatterplot(data_2, x='Result',y='SC') #No Correlation
# Out:
# <Axes: xlabel='Result', ylabel='SC'>

# %%
sns.countplot(x='Result', hue='Gender', data=data_2)
# Out:
# <Axes: xlabel='Result', ylabel='count'>

# %%
sns.histplot(data=data_2, x='Age', hue='Result', bins=50, multiple='stack')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
#Correlation
data_2.corr()
# Out:
#               Age    Gender       CPT       RBP        SC       FBS       RER  \
# Age      1.000000 -0.094401  0.096920  0.273053  0.220056  0.123458  0.128171
# Gender  -0.094401  1.000000  0.034636 -0.062693 -0.201647  0.042140  0.039253
# CPT      0.096920  0.034636  1.000000 -0.043196  0.090465 -0.098537  0.074325
# RBP      0.273053 -0.062693 -0.043196  1.000000  0.173019  0.155681  0.116157
# SC       0.220056 -0.201647  0.090465  0.173019  1.000000  0.025186  0.167652
# FBS      0.123458  0.042140 -0.098537  0.155681  0.025186  1.000000  0.053499
# RER      0.128171  0.039253  0.074325  0.116157  0.167652  0.053499  1.000000
# MHR     -0.402215 -0.076101 -0.317682 -0.039136 -0.018739  0.022494 -0.074628
# EIA      0.098297  0.180022  0.353160  0.082793  0.078243 -0.004107  0.095098
# oldpeak  0.194234  0.097412  0.167244  0.222800  0.027709 -0.025538  0.120034
# ST       0.159774  0.050545  0.136900  0.142472 -0.005755  0.044076  0.160614
# ...

# %%
#Normalization of the data
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler

# %%
data_2.values
# Out:
# array([[70.,  1.,  4., ...,  3.,  3.,  2.],
#        [67.,  0.,  3., ...,  0.,  7.,  1.],
#        [57.,  1.,  2., ...,  0.,  7.,  2.],
#        ...,
#        [56.,  0.,  2., ...,  0.,  3.,  1.],
#        [57.,  1.,  4., ...,  0.,  6.,  1.],
#        [67.,  1.,  4., ...,  3.,  3.,  2.]])

# %%
array = data_2.values

scaler = MinMaxScaler(feature_range=(0,1))
rescaledX = scaler.fit_transform(array)

#transformed data
set_printoptions(precision=2)
print(rescaledX[0:5,:])
# Out:
# [[0.85 1.   1.   0.34 0.45 0.   1.   0.29 0.   0.39 0.5  1.   0.   1.  ]
#  [0.79 0.   0.67 0.2  1.   0.   1.   0.68 0.   0.26 0.5  0.   1.   0.  ]
#  [0.58 1.   0.33 0.28 0.31 0.   0.   0.53 0.   0.05 0.   0.   1.   1.  ]
#  [0.73 1.   1.   0.32 0.31 0.   0.   0.26 1.   0.03 0.5  0.33 1.   0.  ]
#  [0.94 0.   0.33 0.25 0.33 0.   1.   0.38 1.   0.03 0.   0.33 0.   0.  ]]

# %%
# Standardize data (0 mean, 1 stdev)
from sklearn.preprocessing import StandardScaler

# %%
array = data_2.values
scaler = StandardScaler().fit(array)
rescaledX = scaler.transform(array)

# summarize transformed data
set_printoptions(precision=2)
print(rescaledX[0:5,:])
# Out:
# [[ 1.71  0.69  0.87 -0.08  1.4  -0.42  0.98 -1.76 -0.7   1.18  0.68  2.47
#   -0.88  1.12]
#  [ 1.38 -1.45 -0.18 -0.92  6.09 -0.42  0.98  0.45 -0.7   0.48  0.68 -0.71
#    1.19 -0.89]
#  [ 0.28  0.69 -1.24 -0.41  0.22 -0.42 -1.03 -0.38 -0.7  -0.66 -0.95 -0.71
#    1.19  1.12]
#  [ 1.05  0.69  0.87 -0.19  0.26 -0.42 -1.03 -1.93  1.43 -0.74  0.68  0.35
#    1.19 -0.89]
#  [ 2.15 -1.45 -1.24 -0.64  0.37 -0.42  0.98 -1.24  1.43 -0.74 -0.95  0.35
#   -0.88 -0.89]]
